# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketkumar2808/GenAI/blob/main/AI_Agents/Exercise_crewai_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise 1: Stock Market Research with CrewAI
# Create an agent using CrewAI to analyze stock market data and generate a concise report.

# %% [markdown]
# #### Hint

# %%
# %pip install crewai 'crewai[tools]' google-search-results langchain_google_genai

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from crewai import LLM

from google.colab import userdata

# Initialize the LLM
# llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest")
os.environ["SERPER_API_KEY"] = "0fd7aaeaad3059112d1ba77e6b691a9c49be5463"
os.environ['GEMINI_API_KEY'] = userdata.get('my_api_key')
llm_gemini = LLM(
    model="gemini/gemini-1.5-flash-latest",
)

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool
# Define tools like Serper API for stock research
search_tool = SerperDevTool()

# Create stock analyst agent
# Added a backstory for the stock_analyst agent
stock_analyst = Agent(role='Stock Analyst', goal='Analyze stock trends',llm = llm_gemini, verbose=True,allow_delegation=False, tools=[search_tool], backstory="A seasoned financial expert with a deep understanding of market dynamics.")
# Create financial analyst and report writer agents
# Added a backstory for the finance_analyst agent
finance_analyst = Agent(role='Stock Analyst', goal='Analyze stock trends',llm = llm_gemini, verbose=True,allow_delegation=False,tools=[search_tool], backstory="A meticulous financial analyst with expertise in risk assessment and forecasting.")

# Define research task
# Added expected_output for the research_task
task_research = Task(description='Research Tesla stock performance', agent=stock_analyst, expected_output="A report on Tesla stock performance.") # Added expected_output
# Create tasks for financial analysis and report writing
# Assuming analysis_task and report_task are defined elsewhere in the code with appropriate agents and descriptions.
# You'll need to define these tasks similarly to task_research, ensuring they have a description and an assigned agent.
analysis_task = Task(description='Analyze financial performance of Tesla', agent=finance_analyst, expected_output="An analysis of Tesla's financial performance.")  # Added expected_output # Replace with your actual analysis task definition
# Added a backstory for the report_writer agent
report_writer = Agent(role='Report Writer', goal='Generate comprehensive reports', tools=[], backstory="A skilled writer with expertise in presenting complex information clearly and concisely.")  # Replace with your actual report writer agent definition
report_task = Task(description='Generate a report on Tesla stock performance', agent=report_writer, expected_output="A comprehensive report on Tesla stock performance.")  # Added expected_output # Replace with your actual report task definition

# Form and run the crew
crew = Crew(agents=[stock_analyst, finance_analyst, report_writer], tasks=[task_research, analysis_task, report_task])
print(crew.kickoff())
# Out:
# # Agent: Stock Analyst
# ## Task: Research Tesla stock performance
#
#
# # Agent: Stock Analyst
# ## Thought: tool_code
# Thought: I need to gather information on Tesla's stock performance.  I'll start with a general search for news and then refine my search as needed.
# ## Using tool: Search the internet with Serper
# ## Tool Input:
# "{\"search_query\": \"Tesla stock performance news\"}"
# ## Tool Output:
# ...

# %% [markdown]
# ### Exercise 2: Create a Marketing Team Crew
# Build a crew of agents to simulate a marketing team creating a campaign for a new product.

# %% [markdown]
# ####Hint

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool

# Define tools like Serper API for market research
search_tool = SerperDevTool()

# Create market researcher agent
# Added backstory for the researcher agent
researcher = Agent(role='Market Researcher', goal='Identify industry trends', tools=[search_tool], backstory="An expert in market research with a deep understanding of consumer behavior and industry trends.",llm=llm_gemini)

# Create copywriter and designer agents
# Added backstory for the copywriter agent
copywriter = Agent(role='Copywriter', goal='To create compelling and persuasive written content', tools=[search_tool], backstory="A skilled copywriter with a talent for crafting engaging and persuasive marketing materials.",llm=llm_gemini)
# Added backstory for the designer agent
designer   = Agent(role='Market Designer', goal='Design industry products', tools=[search_tool], backstory="A creative designer with a keen eye for aesthetics and a deep understanding of user experience.",llm=llm_gemini)

# Define research task
# Added expected_output for the research_task
research_task = Task(description='Analyze trending topics in eco-friendly products', agent=researcher, expected_output="A report on trending topics in eco-friendly products.")

# Create tasks for ad copy and visual design
# Added expected_output for the copy_task
copy_task = Task(description='Create compelling and persuasive written content', agent=copywriter, expected_output="Compelling and persuasive written content for marketing materials.")  # Changed agent to copywriter
# Added expected_output for the design_task
design_task = Task(description='Design latest trending and eco-friendly products', agent=designer, expected_output="Designs for latest trending and eco-friendly products.")  # Changed agent to designer

# Form and run the crew
crew = Crew(agents=[researcher, copywriter, designer], tasks=[research_task, copy_task, design_task])
print(crew.kickoff())
# Out:
# **Design Concepts for Latest Trending and Eco-Friendly Products:**
#
# **I. Sustainable Apparel:**
#
# * **Product:** Organic Cotton T-shirt with Minimalist Design.
# * **Materials:** 100% GOTS-certified organic cotton.
# * **Packaging:**  Recycled cardboard mailer with minimal printing, compostable packing peanuts.
# * **Design Features:** Simple, modern design with focus on high-quality fabric and comfortable fit.  Ethically sourced and produced.
#
#
# * **Product:** Recycled Polyester Hoodie.
# * **Materials:**  Made from recycled plastic bottles, reducing landfill waste.
# * **Packaging:**  Recycled and recyclable paper bag with minimal branding.
# * **Design Features:**  Stylish, comfortable hoodie with durable construction.  Durable water-repellent finish without using harmful chemicals.
#
#
# **II. Personal Care & Cosmetics:**
#
# * **Product:** Vegan and Cruelty-Free Shampoo Bar.
# * **Materials:**  Biodegradable palm oil-free soap base, ethically sourced essential oils.
# ...
